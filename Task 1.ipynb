# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_17 = pd.read_csv("FIFA17_official_data.csv")
df_18 = pd.read_csv("FIFA18_official_data.csv")
df_19 = pd.read_csv("FIFA19_official_data.csv")
df_20 = pd.read_csv("FIFA20_official_data.csv")
df_21 = pd.read_csv("FIFA21_official_data.csv")
df_22 = pd.read_csv("FIFA22_official_data.csv")
df_23 = pd.read_csv("FIFA23_official_data.csv")

# %%
df_17.head()
# Out:
#        ID            Name  Age  \
# 0  176580       L. Suárez   29
# 1  178518   R. Nainggolan   28
# 2  181872        A. Vidal   29
# 3  197445        D. Alaba   24
# 4  195864        P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# ...

# %%
print(df_17.shape)
print(df_18.shape)
print(df_19.shape)
print(df_20.shape)
print(df_21.shape)
print(df_22.shape)
print(df_23.shape)
# Out:
# (17560, 63)
# (17927, 64)
# (17943, 64)
# (17104, 65)
# (17108, 65)
# (16710, 65)
# (17660, 29)

# %%
df_17.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Loaned From             16227
# Joined                   1695
# Contract Valid Until      362
# Club                      243
# Position                   19
# Jersey Number              19
# Jumping                     0
# Stamina                     0
# ID                          0
# LongShots                   0
# dtype: int64

# %%
df_18.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Loaned From             16445
# Joined                   1864
# Release Clause           1748
# Contract Valid Until      382
# Club                      252
# Position                   19
# Jersey Number              19
# Stamina                     0
# Strength                    0
# Jumping                     0
# dtype: int64

# %%
df_19.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Loaned From             16355
# Joined                   1956
# Release Clause           1841
# Contract Valid Until      368
# Club                      238
# Position                   14
# Jersey Number              14
# Stamina                     0
# Strength                    0
# Jumping                     0
# dtype: int64

# %%
df_20.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Loaned From             15718
# Marking                 15418
# Release Clause           2317
# Joined                   1985
# DefensiveAwareness       1686
# Contract Valid Until      577
# Composure                 420
# Club                      388
# Balance                    39
# Curve                      39
# dtype: int64

# %%
df_21.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Loaned From             16186
# Marking                 16166
# Release Clause           1629
# Joined                   1449
# DefensiveAwareness        942
# Contract Valid Until      496
# Club                      325
# Composure                 287
# Balance                    39
# Curve                      39
# dtype: int64

# %%
df_22.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Marking                 15818
# Loaned From             15578
# Release Clause           1749
# Joined                   1512
# DefensiveAwareness        892
# Contract Valid Until      351
# Club                      264
# Composure                 251
# Balance                    37
# Curve                      37
# dtype: int64

# %%
df_23.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# Best Overall Rating     17639
# Loaned From             16966
# Release Clause           1151
# Joined                   1098
# Contract Valid Until      361
# Club                      211
# Real Face                  38
# Body Type                  38
# Kit Number                 35
# Position                   35
# dtype: int64

# %%
def compare_cols(df1,df2):
    print("Length of first: ",len(df1.columns))
    print("Length for second: ",len(df2.columns))
    count=0
    for col in df1.columns:
        if col in df2.columns:
            count+=1
    print("Number of common:",count)

    if count != 0 :
            if(len(df1.columns)>=len(df2.columns)):
                for col in df_17.columns:
                    if col not in df_18.columns:
                        print(col)
            else:
                for col in df2:
                    if col not in df1:
                        print(col)

# %%
compare_cols(df_17,df_18)
# Out:
# Length of first:  63
# Length for second:  64
# Number of common: 63
# Release Clause

# %%
compare_cols(df_18,df_19)
# Out:
# Length of first:  64
# Length for second:  64
# Number of common: 64

# %%
compare_cols(df_19,df_20)
# Out:
# Length of first:  64
# Length for second:  65
# Number of common: 64
# DefensiveAwareness

# %%
compare_cols(df_20,df_21)
# Out:
# Length of first:  65
# Length for second:  65
# Number of common: 65

# %%
compare_cols(df_21,df_22)
# Out:
# Length of first:  65
# Length for second:  65
# Number of common: 65

# %%
compare_cols(df_22,df_23)

# Bruh
# Out:
# Length of first:  65
# Length for second:  29
# Number of common: 28

# %%
cols = []

for col in df_22.columns:
    if col not in df_23.columns:
        cols.append(col)
print(cols)
# Out:
# ['Jersey Number', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'DefensiveAwareness']

# %%
cols = []

for col in df_22.columns:
    if col in df_23.columns:
        cols.append(col)
print(cols)
# Out:
# ['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Best Overall Rating', 'Release Clause']

# %% [markdown]
# So 17-22 can be merged for year on year analysis but 23 is in a completely different format

# %%
df_22.columns

# why so many columns 🙏😭
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'Release Clause',
# ...

# %% [markdown]
# Had 2 options for yearly analysis:
#
# a - create functions and run them on each dataset
#
# b - create a mega dataset with all combined and use group by operations
#
# b seems better to avoid looping through each dataset for each function

# %%
#Adding a year clumn so once we combine all datasets we can still perform year wise analysis

df_17["year"]=2017
df_18["year"]=2018
df_19["year"]=2019
df_20["year"]=2020
df_21["year"]=2021
df_22["year"]=2022
df_23["year"]=2023

# %%
#  Merging the datasets 

dfs = [df_17,df_18,df_19,df_20,df_21,df_22,df_23]
df = pd.concat(dfs,axis=0)

# %%
df.shape
# Out:
# (122012, 67)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'year', 'Release Clause',
# ...

# %% [markdown]
# Year wise analysis

# %%
df.reset_index(inplace=True)

# %%
df.groupby("year")["Age"].idxmin()
# Out:
# year
# 2017     13211
# 2018     29298
# 2019     50559
# 2020     56156
# 2021     77284
# 2022     94591
# 2023    121988
# Name: Age, dtype: int64

# %%
df.loc[11738]["Age"]
# Out:
# 25

# %%
# Youngest Player in each year

df.loc[df.groupby("year")["Age"].idxmin()][["Name","Age","year"]]
# Out:
#                  Name  Age  year
# 13211       E. Håland   15  2017
# 29298      C. Bassett   15  2018
# 50559     S. Anderson   15  2019
# 56156       A. Hložek   16  2020
# 77284      A. Karabec   16  2021
# 94591            Gavi   16  2022
# 121988  22 D. Oncescu   15  2023

# %%
# Oldest Player in each year

df.loc[df.groupby("year")["Age"].idxmax()][["Name","Age","year"]]
# Out:
#                   Name  Age  year
# 17482    B. Richardson   46  2017
# 33375         O. Pérez   44  2018
# 51254         O. Pérez   45  2019
# 70391         S. Royce   47  2020
# 85446         K. Miura   53  2021
# 102377        K. Miura   54  2022
# 119624     22 K. Miura   54  2023

# %%
# Best performers v=over the years

df.groupby("year")[["Name", "Overall"]].apply(lambda x: x.sort_values(by="Overall",ascending=False)[:3])
# Out:
#                            Name  Overall
# year
# 2017 9        Cristiano Ronaldo       94
#      58                L. Messi       93
#      0                L. Suárez       92
# 2018 17571    Cristiano Ronaldo       94
#      17615             L. Messi       94
#      17715               Neymar       92
# 2019 35505    Cristiano Ronaldo       94
#      35509             L. Messi       94
#      35575            Neymar Jr       92
# 2020 53441             L. Messi       94
#      53451    Cristiano Ronaldo       93
#      53492            Neymar Jr       92
# 2021 70552             L. Messi       93
#      70556    Cristiano Ronaldo       92
#      70604            Neymar Jr       91
# 2022 87671             L. Messi       93
#      87675       R. Lewandowski       92
#      101886            J. Oblak       91
# 2023 104393      R. Lewandowski       91
#      104476          K. Benzema       91
#      104355        K. De Bruyne       91

# %%
# Players with highest potential

df.groupby("year")[["Name", "Potential"]].apply(lambda x: x.sort_values(by="Potential",ascending=False)[:3])
# Out:
#                            Name  Potential
# year
# 2017 9        Cristiano Ronaldo         94
#      4                 P. Pogba         94
#      168                 Neymar         94
# 2018 17615             L. Messi         94
#      17795            K. Mbappé         94
#      17762            P. Dybala         94
# 2019 35619            K. Mbappé         95
#      35509             L. Messi         94
#      35505    Cristiano Ronaldo         94
# 2020 53566            K. Mbappé         95
#      54530            J. Sancho         94
#      53441             L. Messi         94
# 2021 70656            K. Mbappé         95
#      70552             L. Messi         93
#      71550            J. Sancho         93
# 2022 87724            K. Mbappé         95
#      87893           E. Haaland         93
#      102250       G. Donnarumma         93
# 2023 104427           K. Mbappé         95
#      104532          E. Haaland         94
#      104566               Pedri         93

# %%
# Best Crossing over the years

df.groupby("year")[["Name", "Crossing"]].apply(lambda x: x.sort_values(by="Crossing",ascending=False)[:3])
# Out:
#                              Name  Crossing
# year
# 2017 4595                A. Pirlo      91.0
#      81              K. De Bruyne      90.0
#      231               S. Larsson      90.0
# 2018 17567           K. De Bruyne      92.0
#      17825        M. Plattenhardt      90.0
#      18303                 P. Max      90.0
# 2019 35491           K. De Bruyne      93.0
#      35510             J. Kimmich      91.0
#      36513               Quaresma      91.0
# 2020 53433           K. De Bruyne      94.0
#      53476    T. Alexander-Arnold      93.0
#      53445             J. Kimmich      91.0
# 2021 70535           K. De Bruyne      94.0
#      70559    T. Alexander-Arnold      93.0
#      71819             Pedro León      92.0
# 2022 87645           K. De Bruyne      94.0
#      87666    T. Alexander-Arnold      92.0
#      89297             Pedro León      91.0
# 2023 104352           L. Goretzka       NaN
#      104353       Bruno Fernandes       NaN
# ...

# %%
# Best Dribbling over the years

df.groupby("year")[["Name", "Dribbling"]].apply(lambda x: x.sort_values(by="Dribbling",ascending=False)[:3])
# Out:
#                         Name  Dribbling
# year
# 2017 58             L. Messi       97.0
#      168              Neymar       96.0
#      199           E. Hazard       93.0
# 2018 17615          L. Messi       97.0
#      17715            Neymar       96.0
#      17684         E. Hazard       94.0
# 2019 35509          L. Messi       97.0
#      35575         Neymar Jr       96.0
#      35592         E. Hazard       95.0
# 2020 53441          L. Messi       97.0
#      53492         Neymar Jr       96.0
#      53550         E. Hazard       95.0
# 2021 70552          L. Messi       96.0
#      70604         Neymar Jr       95.0
#      71129     19 Y. Brahimi       93.0
# 2022 87671          L. Messi       96.0
#      87706         Neymar Jr       95.0
#      87724         K. Mbappé       93.0
# 2023 104352      L. Goretzka        NaN
#      104353  Bruno Fernandes        NaN
#      104354         M. Acuña        NaN

# %%
# Best Finishing over the years

df.groupby("year")[["Name", "Finishing"]].apply(lambda x: x.sort_values(by="Finishing",ascending=False)[:3])
# Out:
#                            Name  Finishing
# year
# 2017 58                L. Messi       95.0
#      0                L. Suárez       94.0
#      9        Cristiano Ronaldo       93.0
# 2018 17615             L. Messi       95.0
#      17560            L. Suárez       94.0
#      17571    Cristiano Ronaldo       94.0
# 2019 35509             L. Messi       95.0
#      35505    Cristiano Ronaldo       94.0
#      35540              H. Kane       94.0
# 2020 53441             L. Messi       95.0
#      53451    Cristiano Ronaldo       94.0
#      53501              H. Kane       94.0
# 2021 70552             L. Messi       95.0
#      70556    Cristiano Ronaldo       95.0
#      70612              H. Kane       94.0
# 2022 87675       R. Lewandowski       95.0
#      87678    Cristiano Ronaldo       95.0
#      87671             L. Messi       95.0
# 2023 104352         L. Goretzka        NaN
#      104353     Bruno Fernandes        NaN
#      104354            M. Acuña        NaN

# %%
# Best Ball Control over the years

df.groupby("year")[["Name", "BallControl"]].apply(lambda x: x.sort_values(by="BallControl",ascending=False)[:3])
# Out:
#                         Name  BallControl
# year
# 2017 168              Neymar         95.0
#      58             L. Messi         95.0
#      211             Iniesta         93.0
# 2018 17615          L. Messi         96.0
#      17715            Neymar         95.0
#      17886           Iniesta         94.0
# 2019 35509          L. Messi         96.0
#      35575         Neymar Jr         95.0
#      35622              Isco         95.0
# 2020 53441          L. Messi         96.0
#      53492         Neymar Jr         95.0
#      53550         E. Hazard         94.0
# 2021 70552          L. Messi         96.0
#      70604         Neymar Jr         95.0
#      70643         P. Dybala         94.0
# 2022 87671          L. Messi         96.0
#      87706         Neymar Jr         95.0
#      87886           15 Xavi         93.0
# 2023 104352      L. Goretzka          NaN
#      104353  Bruno Fernandes          NaN
#      104354         M. Acuña          NaN

# %%
# Highest FreeKick Accuracy over the years
df.groupby("year")[["Name", "FKAccuracy"]].apply(lambda x: x.sort_values(by="FKAccuracy",ascending=False)[:3])
# Out:
#                         Name  FKAccuracy
# year
# 2017 4595           A. Pirlo        93.0
#      35            M. Pjanić        91.0
#      224            D. Payet        91.0
# 2018 17815     H. Çalhanoğlu        93.0
#      18665       S. Giovinco        93.0
#      17615          L. Messi        92.0
# 2019 35509          L. Messi        94.0
#      36706       S. Giovinco        93.0
#      35524         M. Pjanić        92.0
# 2020 53441          L. Messi        94.0
#      59133       18 A. Pirlo        93.0
#      54844       S. Giovinco        92.0
# 2021 70552          L. Messi        94.0
#      70618            Parejo        93.0
#      76636       18 A. Pirlo        93.0
# 2022 87671          L. Messi        94.0
#      94382       18 A. Pirlo        93.0
#      87781    J. Ward-Prowse        92.0
# 2023 104352      L. Goretzka         NaN
#      104353  Bruno Fernandes         NaN
#      104354         M. Acuña         NaN

# %%
# Highest FreeKick Accuracy over the years
df.groupby("year")[["Name", "Penalties"]].apply(lambda x: x.sort_values(by="Penalties",ascending=False)[:3])
# Out:
#                         Name  Penalties
# year
# 2017 3305         R. Lambert       96.0
#      2591       M. Balotelli       92.0
#      118      Z. Ibrahimović       91.0
# 2018 19132      M. Balotelli       92.0
#      17670           Fabinho       91.0
#      17593         L. Baines       90.0
# 2019 35803          M. Kruse       92.0
#      37398      M. Balotelli       92.0
#      37224         S. Haller       91.0
# 2020 59120      16 C. Blanco       94.0
#      53854          M. Kruse       92.0
#      53492         Neymar Jr       92.0
# 2021 81045      09 J. Maatje       94.0
#      76642      16 C. Blanco       94.0
#      70604         Neymar Jr       92.0
# 2022 91800     17 R. Lambert       96.0
#      94359      16 C. Blanco       94.0
#      87706         Neymar Jr       93.0
# 2023 104352      L. Goretzka        NaN
#      104353  Bruno Fernandes        NaN
#      104354         M. Acuña        NaN

# %%
# Best Interception over the years
df.groupby("year")[["Name", "Interceptions"]].apply(lambda x: x.sort_values(by="Interceptions",ascending=False)[:3])
# Out:
#                          Name  Interceptions
# year
# 2017 4014         A. Barzagli           92.0
#      72          Thiago Silva           91.0
#      68              N. Kanté           91.0
# 2018 17860         M. Hummels           92.0
#      17613           N. Kanté           91.0
#      18317         L. Bonucci           90.0
# 2019 35529           N. Kanté           92.0
#      36094         M. Hummels           92.0
#      36443         L. Bonucci           90.0
# 2020 66096      09 P. Maldini           95.0
#      65897    10 F. Cannavaro           93.0
#      53547         17 P. Lahm           93.0
# 2021 83579      09 P. Maldini           95.0
#      81153      08 C. Ramelow           94.0
#      83411    10 F. Cannavaro           93.0
# 2022 101165     09 P. Maldini           95.0
#      100993   10 F. Cannavaro           93.0
#      87767         17 P. Lahm           93.0
# 2023 104352       L. Goretzka            NaN
#      104353   Bruno Fernandes            NaN
# ...

# %%
# Standing Tackle

df.groupby("year")[["Name", "StandingTackle"]].apply(lambda x: x.sort_values(by="StandingTackle",ascending=False)[:3])
# Out:
#                          Name  StandingTackle
# year
# 2017 600           J. Boateng            92.0
#      437           M. Hummels            92.0
#      2745        G. Chiellini            92.0
# 2018 20055       G. Chiellini            92.0
#      17860         M. Hummels            92.0
#      17625       Sergio Ramos            90.0
# 2019 38375       G. Chiellini            93.0
#      35855    T. Alderweireld            91.0
#      35529           N. Kanté            91.0
# 2020 53631        V. van Dijk            93.0
#      53494           N. Kanté            91.0
#      56830       G. Chiellini            90.0
# 2021 70738        V. van Dijk            93.0
#      81153      08 C. Ramelow            91.0
#      70620           N. Kanté            90.0
# 2022 87713           N. Kanté            93.0
#      87883        V. van Dijk            92.0
#      87860           W. Ndidi            90.0
# 2023 104352       L. Goretzka             NaN
# ...

# %%
# Sliding Tackle
df.groupby("year")[["Name", "SlidingTackle"]].apply(lambda x: x.sort_values(by="SlidingTackle",ascending=False)[:3])
# Out:
#                         Name  SlidingTackle
# year
# 2017 600          J. Boateng           91.0
#      71         Sergio Ramos           90.0
#      2745       G. Chiellini           90.0
# 2018 17625      Sergio Ramos           91.0
#      20055      G. Chiellini           90.0
#      17860        M. Hummels           90.0
# 2019 38375      G. Chiellini           90.0
#      35504      Sergio Ramos           90.0
#      35492     R. Nainggolan           90.0
# 2020 53547        17 P. Lahm           95.0
#      54387    A. Wan-Bissaka           90.0
#      53450      Sergio Ramos           90.0
# 2021 70658        17 P. Lahm           95.0
#      71334    A. Wan-Bissaka           90.0
#      70541     R. Nainggolan           90.0
# 2022 87767        17 P. Lahm           95.0
#      88510    A. Wan-Bissaka           92.0
#      87654      Sergio Ramos           91.0
# 2023 104352      L. Goretzka            NaN
#      104353  Bruno Fernandes            NaN
# ...

# %%
# Making one metric for goal keepers rather than having 5 separate

df["GKOverall"] = (df["GKDiving"] + df["GKHandling"] + df["GKKicking"] + df["GKPositioning"] + df["GKReflexes"])/5

# %%
# Best Goalkeepers 

df.groupby("year")[["Name", "GKOverall"]].apply(lambda x: x.sort_values(by="GKOverall",ascending=False)[:3])
# Out:
#                         Name  GKOverall
# year
# 2017 12372          M. Neuer       90.8
#      13739            De Gea       87.2
#      15601           P. Čech       83.8
# 2018 30272          M. Neuer       91.2
#      30712            De Gea       88.6
#      33157     M. ter Stegen       86.0
# 2019 50629     M. ter Stegen       87.6
#      48859          M. Neuer       87.2
#      49081            De Gea       87.2
# 2020 66690     M. ter Stegen       87.8
#      67550           Alisson       87.8
#      65181          M. Neuer       87.6
# 2021 82680          M. Neuer       88.0
#      84145     M. ter Stegen       87.8
#      84924           Alisson       87.8
# 2022 99992          M. Neuer       88.8
#      101532    M. ter Stegen       87.8
#      98834           Ederson       87.6
# 2023 104352      L. Goretzka        NaN
#      104353  Bruno Fernandes        NaN
#      104354         M. Acuña        NaN

# %% [markdown]
# Overall Analysis (2017-2023)

# %%
df.head()
# Out:
#    index      ID            Name  Age  \
# 0      0  176580       L. Suárez   29
# 1      1  178518   R. Nainggolan   28
# 2      2  181872        A. Vidal   29
# 3      3  197445        D. Alaba   24
# 4      4  195864        P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# ...

# %%
# Highest Overall Rating

df.groupby("Name")["Overall"].mean().sort_values(ascending=False)[:10]
# Out:
# Name
#  L. Messi             93.600000
#  Cristiano Ronaldo    93.400000
#  Neymar               92.000000
# L. Messi              92.000000
#  Neymar Jr            91.666667
# R. Lewandowski        91.500000
# K. Mbappé             91.000000
# K. De Bruyne          91.000000
#  R. Lewandowski       90.600000
# Cristiano Ronaldo     90.500000
# Name: Overall, dtype: float64

# %%
df["Name"] = df["Name"].str.strip()

# %%
# Highest Overall Rating

df.groupby("Name")["Overall"].mean().sort_values(ascending=False)[:10]
# Out:
# Name
# L. Messi             93.142857
# Cristiano Ronaldo    92.571429
# Neymar               92.000000
# Neymar Jr            91.000000
# R. Lewandowski       90.857143
# K. De Bruyne         90.571429
# M. Neuer             90.000000
# J. Oblak             89.857143
# T. Courtois          88.857143
# S. Agüero            88.833333
# Name: Overall, dtype: float64

# %%
df["Name"] = df["Name"].str.replace("Neymar Jr","Neymar")

# %%
# Highest Overall Rating

df.groupby("Name")["Overall"].mean().sort_values(ascending=False)[:10]
# Out:
# Name
# L. Messi             93.142857
# Cristiano Ronaldo    92.571429
# Neymar               91.285714
# R. Lewandowski       90.857143
# K. De Bruyne         90.571429
# M. Neuer             90.000000
# J. Oblak             89.857143
# T. Courtois          88.857143
# S. Agüero            88.833333
# L. Modrić            88.571429
# Name: Overall, dtype: float64

# %%
# Highest Potenital Rating

df.groupby("Name")["Potential"].mean().sort_values(ascending=False)[:10]
# Out:
# Name
# K. Mbappé            94.428571
# L. Messi             93.142857
# Cristiano Ronaldo    92.571429
# G. Donnarumma        92.571429
# J. Oblak             92.428571
# E. Haaland           92.250000
# 09 L. Hoedemaker     92.000000
# Vinícius Júnior      92.000000
# Vinícius Jr.         91.750000
# Neymar               91.714286
# Name: Potential, dtype: float64

# %%
df["Name"] = df["Name"].str.replace("Vinícius Júnior","Vinícius Jr.")

# %%
# Highest Potenital Rating

df.groupby("Name")["Potential"].mean().sort_values(ascending=False)[:10]
# Out:
# Name
# K. Mbappé            94.428571
# L. Messi             93.142857
# G. Donnarumma        92.571429
# Cristiano Ronaldo    92.571429
# J. Oblak             92.428571
# E. Haaland           92.250000
# 09 L. Hoedemaker     92.000000
# Vinícius Jr.         91.800000
# Neymar               91.714286
# João Félix           91.200000
# Name: Potential, dtype: float64

# %%
# Highest Potenital Rating

df.groupby("Name")["GKOverall"].mean().sort_values(ascending=False)[:10]
# Out:
# Name
# M. Neuer             88.933333
# M. ter Stegen        86.733333
# J. Oblak             86.400000
# De Gea               85.466667
# Ederson              85.300000
# Alisson              84.733333
# 11 E. van der Sar    84.400000
# 21 A. Onana          84.000000
# T. Courtois          83.833333
# S. Handanovič        83.533333
# Name: GKOverall, dtype: float64

# %%
# Country wise average of rating of players between 2017 and 2023

df.groupby("Nationality")["Overall"].mean().sort_values(ascending=False)[:10]

# Not very useful since could either be skewed low number of players and few good ones leading to a higher avergae
# Out:
# Nationality
# Mozambique             71.703704
# Brazil                 71.325113
# Algeria                70.662304
# Syria                  70.392857
# Portugal               70.353355
# São Tomé & Príncipe    70.333333
# Czech Republic         70.315372
# Egypt                  70.195021
# São Tomé e Príncipe    70.000000
# Libya                  70.000000
# Name: Overall, dtype: float64

# %%
df.groupby("Nationality")["Overall"].mean().sort_values()[:10]

# Not very useful since could either be skewed low number of players and few good ones leading to a higher avergae
# Out:
# Nationality
# South Sudan          54.750000
# Indonesia            54.750000
# San Marino           55.333333
# India                55.410256
# Singapore            55.500000
# Brunei Darussalam    56.333333
# Yemen                58.000000
# China PR             58.419932
# Hong Kong            59.230769
# Guyana               59.488889
# Name: Overall, dtype: float64

# %%
df.groupby("Club")["Overall"].mean().sort_values(ascending=False)[:10]

# Again skewed a little by low sample clubs
# Out:
# Club
# 111648               85.000000
# Messina              80.000000
# Juventus             79.609302
# Siena                79.000000
# FC Bayern München    78.269231
# AFC Richmond         78.066667
# Real Madrid          78.058824
# FC Barcelona         77.864000
# Napoli               77.844920
# Inter                77.331858
# Name: Overall, dtype: float64

# %%
df.groupby("Club")["Overall"].mean().sort_values()[:10]

# Not very useful since could either be skewed low number of players and few good ones leading to a higher avergae
# Out:
# Club
# Arezzo                           28.000000
# Al Nahdha Dammam                 49.000000
# Dagenham and Redbridge           51.000000
# Wexford Youths                   51.826087
# Longford Town                    52.228571
# Chengdu Rongcheng F.C.           52.250000
# Chongqing Liangjiang Athletic    52.393939
# Galway United                    52.660714
# UCD AFC                          52.789474
# Torquay United                   53.000000
# Name: Overall, dtype: float64

# %% [markdown]
# Club wise

# %%
# Enter a club and see its best performers

def club_perf(club):
    return (
        df[df["Club"] == club][["Name","Overall"]]
        .sort_values(by="Overall", ascending=False)
        .drop_duplicates(subset="Name", keep="first")[["Name", "Overall"]][:10]
    )

club_perf("FC Barcelona")
# Out:
#                    Name  Overall
# 35509          L. Messi       94
# 0             L. Suárez       92
# 168              Neymar       92
# 104393   R. Lewandowski       91
# 66690     M. ter Stegen       90
# 53431      A. Griezmann       89
# 35814   Sergio Busquets       89
# 36246             Piqué       88
# 211             Iniesta       88
# 35594         S. Umtiti       87

# %% [markdown]
# Nation Wise

# %%
# Nation wise best preformers

def nation_perf(nation):
    return (
        df[df["Nationality"] == nation][["Name","Overall"]]
        .sort_values(by="Overall", ascending=False)
        .drop_duplicates(subset="Name", keep="first")[["Name", "Overall"]][:10]
    )

nation_perf("France")
# Out:
#                 Name  Overall
# 104476    K. Benzema       91
# 104427     K. Mbappé       91
# 87713       N. Kanté       90
# 35488   A. Griezmann       89
# 17564       P. Pogba       88
# 15317      H. Lloris       88
# 114619    M. Maignan       87
# 71576     A. Laporte       87
# 35594      S. Umtiti       87
# 55188      R. Varane       86

# %%
df["Name"].unique()
# Out:
# array(['L. Suárez', 'R. Nainggolan', 'A. Vidal', ..., '22\xa0Lim Jun Sub',
#        '21\xa0S. Czajor', '21\xa0F. Jakobsson'], dtype=object)

# %%
def Player_perf(players):
    for player in players:
        player_df = df[df["Name"] == player]
        plt.plot(player_df["year"],player_df["Overall"],label=player)
        plt.ylim(0,100)
        plt.legend()
Player_perf(["Cristiano Ronaldo","L. Messi","P. Pogba"])

# %% [markdown]
# ## Model Fitting

# %%
df.head()
# Out:
#    index      ID           Name  Age  \
# 0      0  176580      L. Suárez   29
# 1      1  178518  R. Nainggolan   28
# 2      2  181872       A. Vidal   29
# 3      3  197445       D. Alaba   24
# 4      4  195864       P. Pogba   23
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/17_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/178/518/17_60.png     Belgium
# 2  https://cdn.sofifa.com/players/181/872/17_60.png       Chile
# 3  https://cdn.sofifa.com/players/197/445/17_60.png     Austria
# 4  https://cdn.sofifa.com/players/195/864/17_60.png      France
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       92         92       FC Barcelona
# 1  https://cdn.sofifa.com/flags/be.png       86         86               Roma
# 2  https://cdn.sofifa.com/flags/cl.png       87         87  FC Bayern München
# ...

# %%
df.columns
# Out:
# Index(['index', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'year', 'Release Clause',
# ...

# %%
df.drop(columns=["index","ID","Name","Photo","Nationality","Flag","Overall","Club","Club Logo","Weak Foot","Best Overall Rating","Jersey Number","Joined","Loaned From","Contract Valid Until","Kit Number","GKOverall","Release Clause"],inplace=True)

# %%
df.shape
# Out:
# (122012, 51)

# %%
df.columns
# Out:
# Index(['Age', 'Potential', 'Value', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Skill Moves', 'Work Rate', 'Body Type',
#        'Real Face', 'Position', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Best Position', 'year',
#        'DefensiveAwareness'],
#       dtype='object')

# %%
# droppign 2023 data cause differnet attributes

df = df[df["year"] != 2023]

# %%
df.shape
# Out:
# (104352, 51)

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Age                          0.000000
# Potential                    0.000000
# Value                        0.000000
# Wage                         0.000000
# Special                      0.000000
# Preferred Foot               0.000000
# International Reputation     0.000000
# Skill Moves                  0.000000
# Work Rate                    0.000000
# Body Type                    0.077622
# Real Face                    0.077622
# Position                     0.112121
# Height                       0.000000
# Weight                       0.000000
# Crossing                     0.000000
# Finishing                    0.000000
# HeadingAccuracy              0.000000
# ShortPassing                 0.000000
# Volleys                      0.110204
# Dribbling                    0.000000
# Curve                        0.110204
# FKAccuracy                   0.000000
# LongPassing                  0.000000
# BallControl                  0.000000
# Acceleration                 0.000000
# ...

# %%
# Marking and Defensisve Awareness need to be dropped due to ~50% null values. Other either specific rows can be dropped as less than 1%

df.drop(columns=["Marking","DefensiveAwareness"],inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.drop(columns="Real Face",inplace=True)

# %%
df.shape

# Lost ~1000 rows. Okay
# Out:
# (103298, 48)

# %%
y = df["Potential"]
X = df.drop(columns="Potential")


from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_test
# Out:
#        Age   Value  Wage  Special Preferred Foot  International Reputation  \
# 7078    26   €375K   €3K     1692          Right                       1.0
# 85001   21   €190K   €1K     1384          Right                       1.0
# 43384   23   €525K   €3K     1675           Left                       1.0
# 80382   27   €2.5M  €10K     1607           Left                       1.0
# 17802   24  €22.5M  €60K     2073           Left                       2.0
# ...    ...     ...   ...      ...            ...                       ...
# 47910   20   €1.1M   €5K     1509          Right                       1.0
# 61170   25   €775K   €2K     1667          Right                       1.0
# 90214   37   €3.4M  €10K     1894          Right                       3.0
# 62508   25   €1.9M   €3K     1620          Right                       1.0
# 24834   21   €1.3M   €6K     1689           Left                       1.0
#
#        Skill Moves       Work Rate         Body Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103298 entries, 0 to 104350
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       103298 non-null  int64
#  1   Potential                 103298 non-null  int64
#  2   Value                     103298 non-null  object
#  3   Wage                      103298 non-null  object
#  4   Special                   103298 non-null  int64
#  5   Preferred Foot            103298 non-null  object
#  6   International Reputation  103298 non-null  float64
#  7   Skill Moves               103298 non-null  float64
#  8   Work Rate                 103298 non-null  object
#  9   Body Type                 103298 non-null  object
#  10  Position                  103298 non-null  object
#  11  Height                    103298 non-null  object
#  12  Weight                    103298 non-null  object
# ...

# %%
# Handling Value 

def value_preprocessing(value):

    temp = value[1:]
    if temp[-1] == "M":
        return float(temp[:-1])*1000000
    elif temp[-1] == "K":
        return float(temp[:-1])*1000
    else:
        return float(temp)
    
df["Value"] = df["Value"].apply(value_preprocessing)

# %%
df["Preferred Foot"] = df["Preferred Foot"].apply(lambda x : 1 if x == "Right" else 0)

# %%
from sklearn.preprocessing import OrdinalEncoder

df[["Attacking Work Rate", "Defensive Work Rate"]] = df["Work Rate"].str.split("/", expand=True)


df["Attacking Work Rate"] = df["Attacking Work Rate"].str.strip()
df["Defensive Work Rate"] = df["Defensive Work Rate"].str.strip()

order = [["Low", "Medium", "High"], ["Low", "Medium", "High"]]
encoder = OrdinalEncoder(categories=order)
df[["Attacking Work Rate", "Defensive Work Rate"]] = encoder.fit_transform(
    df[["Attacking Work Rate", "Defensive Work Rate"]]
).astype(int)
df.drop(columns=["Work Rate"],inplace=True)

# %%
df["Body Type"].unique()

# Seems better to drop than preprocess this

df.drop(columns=["Body Type"],inplace=True)

# %%
df["Best Position"].unique()
# Out:
# array(['ST', 'CDM', 'LB', 'CAM', 'RB', 'LWB', 'CM', 'RWB', 'RM', 'LM',
#        'CB', 'LW', 'CF', 'RW', 'GK'], dtype=object)

# %%
# Seems redundant since we have best position which is already pre processed

df.drop(columns=["Position"],inplace=True)

# %%
df["Height"]
# Out:
# 0           6'0
# 1           5'9
# 2          5'11
# 3          5'11
# 4           6'3
#           ...
# 104346    195cm
# 104347    188cm
# 104348    194cm
# 104349    180cm
# 104350    186cm
# Name: Height, Length: 103298, dtype: object

# %%
def height_to_cm(height):
    if pd.isnull(height):
        return None
    height = str(height).strip()
    
    if "'" in height:
        feet, inches = height.split("'")
        total_inches = int(feet) * 12 + int(inches)
        return round(total_inches * 2.54, 1)  
    else: 
        return float(height.replace("cm", ""))


df["Height"] = df["Height"].apply(height_to_cm)

# %%
def handle_weights(weight):
    if pd.isnull(weight):
        return None  # handle missing values
    weight = str(weight).strip()
    if "kg" in weight:
        return float(weight.replace("kg","").strip()) * 2.20462  # kg to lbs
    elif "lbs" in weight:
        return float(weight.replace("lbs","").strip())
    else:
        return None  # unknown format

# Apply to the column
df["Weight"] = df["Weight"].apply(handle_weights)

# %%
df.drop(columns="Wage",inplace=True)

# %%
df.head()
# Out:
#    Age  Potential       Value  Special  Preferred Foot  \
# 0   29         92  83000000.0     2291               1
# 1   28         86  37500000.0     2290               1
# 2   29         87  41500000.0     2285               1
# 3   24         89  41500000.0     2279               0
# 4   23         94  71500000.0     2271               1
#
#    International Reputation  Skill Moves  Height  Weight  Crossing  ...  \
# 0                       5.0          4.0   182.9   190.0      77.0  ...
# 1                       3.0          3.0   175.3   143.0      73.0  ...
# 2                       4.0          3.0   180.3   165.0      76.0  ...
# 3                       4.0          3.0   180.3   168.0      82.0  ...
# 4                       4.0          5.0   190.5   185.0      78.0  ...
#
#    SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0           38.0      27.0        25.0       31.0           33.0        37.0
# ...

# %%
df["Best Position"].unique()
# Out:
# array(['ST', 'CDM', 'LB', 'CAM', 'RB', 'LWB', 'CM', 'RWB', 'RM', 'LM',
#        'CB', 'LW', 'CF', 'RW', 'GK'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop='first')  

encoded_data = encoder.fit_transform(df[['Best Position']])

encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['Best Position']))
df= pd.concat([df, encoded_df], axis=1)
df.drop("Best Position", axis=1, inplace=True)

# %%
# Missing values somehow

df = df.dropna()

# %%
df.shape
# Out:
# (102262, 59)

# %%
df.corr()["Potential"].sort_values(ascending=True)[:10]
# Out:
# Age                -0.232851
# Best Position_GK   -0.127768
# Best Position_CB   -0.078777
# GKKicking          -0.044427
# GKDiving           -0.038608
# GKHandling         -0.038596
# GKReflexes         -0.038046
# GKPositioning      -0.037546
# Preferred Foot     -0.027316
# Weight             -0.022384
# Name: Potential, dtype: float64

# %%
df.corr()["Potential"].sort_values(ascending=False)[:10]
# Out:
# Potential                   1.000000
# Value                       0.556088
# Reactions                   0.503877
# Composure                   0.403638
# Special                     0.378633
# ShortPassing                0.362852
# BallControl                 0.343424
# International Reputation    0.342959
# Vision                      0.338099
# LongPassing                 0.317819
# Name: Potential, dtype: float64

# %%
y = df["Potential"]
X = df.drop(columns="Potential")


from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import r2_score,mean_squared_error


y_pred = dt.predict(X_test)
r2 = r2_score(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print("R2 score: ",r2,"Mean Squared Error: " , mse )
# Out:
# R2 score:  0.9010888569589379 Mean Squared Error:  3.526377548525889

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# Train the model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict on test data
y_pred_lr = lr.predict(X_test)
r2_lr_test = r2_score(y_test, y_pred_lr)
mse_lr_test = mean_squared_error(y_test, y_pred_lr)

# Predict on training data
y_train_pred_lr = lr.predict(X_train)
r2_lr_train = r2_score(y_train, y_train_pred_lr)
mse_lr_train = mean_squared_error(y_train, y_train_pred_lr)

# Print results clearly
print("Linear Regression Performance")
print(f"Training -> R2: {r2_lr_train:.4f}, MSE: {mse_lr_train:.4f}")
print(f"Testing  -> R2: {r2_lr_test:.4f}, MSE: {mse_lr_test:.4f}")
# Out:
# Linear Regression Performance
# Training -> R2: 0.7086, MSE: 10.4764
# Testing  -> R2: 0.7045, MSE: 10.5334

# %% [markdown]
# Underfitting sicnce doing poorly on both. will try polynomial later

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

r2_dt = r2_score(y_test, y_pred_dt)
mse_dt = mean_squared_error(y_test, y_pred_dt)

print("Decision Tree R2 score:", r2_dt, "Mean Squared Error:", mse_dt)
# Out:
# Decision Tree R2 score: 0.8989536105157498 Mean Squared Error: 3.602503300249352

# %%
from sklearn.ensemble import RandomForestRegressor

# Create model
rf = RandomForestRegressor(
    n_estimators=20,       # fewer trees for speed
    n_jobs=-1,             # use all CPU cores
    random_state=42
)

rf.fit(X_train, y_train)

# Predict
y_pred_rf = rf.predict(X_test)

# Evaluate
r2_rf = r2_score(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
print("Random Forest -> R2:", r2_rf, "MSE:", mse_rf)
# Out:
# Random Forest -> R2: 0.9488480046651335 MSE: 1.8236696328167017

# %% [markdown]
# Nice. Random Forest does well

# %% [markdown]
# Polynomial Reg

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# 1️⃣ Create polynomial features
degree = 2  # adjust 2 or 3
poly = PolynomialFeatures(degree=degree, include_bias=False)

X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# 2️⃣ Train Linear Regression
lr_poly = LinearRegression()
lr_poly.fit(X_train_poly, y_train)

# 3️⃣ Predict
y_train_pred = lr_poly.predict(X_train_poly)
y_test_pred = lr_poly.predict(X_test_poly)

# 4️⃣ Evaluate
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

# 5️⃣ Print results
print(f"Polynomial Regression (degree={degree}) Performance")
print(f"Training -> R2: {r2_train:.4f}, MSE: {mse_train:.4f}")
print(f"Testing  -> R2: {r2_test:.4f}, MSE: {mse_test:.4f}")
# Out:
# Polynomial Regression (degree=2) Performance
# Training -> R2: 0.8884, MSE: 4.0130
# Testing  -> R2: 0.8822, MSE: 4.1990

# %% [markdown]
# Better. deg 3 was taking too long to train

# %% [markdown]
# Neural Net approach

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(1)  # Single neuron output, no activation for regression
])
batch_size = 256

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='mse',  # Mean Squared Error for regression
              metrics=['mae'])  # Mean Absolute Error as a metric
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=batch_size,
)

import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss (MSE)')
plt.plot(history.history['val_loss'], label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title('Training and Validation Loss')
plt.legend()

# 2. Metric (MAE)
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('Training and Validation MAE')
plt.legend()
# Out:
# Epoch 1/50
# c:\Users\LAVESH\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2945.2180 - mae: 49.2154 - val_loss: 113.4528 - val_mae: 8.4160
# Epoch 2/50
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 85.7116 - mae: 7.2849 - val_loss: 49.7931 - val_mae: 5.5518
# Epoch 3/50
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44.3819 - mae: 5.2389 - val_loss: 33.8407 - val_mae: 4.5604
# Epoch 4/50
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 30.8333 - mae: 4.3621 - val_loss: 25.2118 - val_mae: 3.9322
# Epoch 5/50
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.2699 - mae: 3.7911 - val_loss: 19.2963 - val_mae: 3.4410
# ...
